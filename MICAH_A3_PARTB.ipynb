# %%
import pandas as pd
data = pd.read_csv('/content/NSSO68main.csv', low_memory=False)

# %%
data.head()
# Out:
#    slno       grp  Round_Centre  FSU_number  Round  Schedule_Number  Sample  \
# 0     1  4.10E+31             1       41000     68               10       1
# 1     2  4.10E+31             1       41000     68               10       1
# 2     3  4.10E+31             1       41000     68               10       1
# 3     4  4.10E+31             1       41000     68               10       1
# 4     5  4.10E+31             1       41000     68               10       1
#
#    Sector  state  State_Region  ...  pickle_v  sauce_jam_v  Othrprocessed_v  \
# 0       2     24           242  ...       0.0          0.0              0.0
# 1       2     24           242  ...       0.0          0.0              0.0
# 2       2     24           242  ...       0.0          0.0              0.0
# 3       2     24           242  ...       0.0          0.0              0.0
# 4       2     24           242  ...       0.0          0.0              0.0
#
#    Beveragestotal_v  foodtotal_v  foodtotal_q  state_1  Region  \
# 0          0.000000  1141.492400    30.942394      GUJ     2.0
# 1         17.500000  1244.553500    29.286153      GUJ     2.0
# 2          0.000000  1050.315400    31.527046      GUJ     2.0
# 3         33.333333  1142.591667    27.834607      GUJ     2.0
# 4         75.000000   945.249500    27.600713      GUJ     2.0
#
#    fruits_df_tt_v  fv_tot
# 0       12.000000  154.18
# 1      333.000000  484.95
# 2       35.000000  214.84
# 3      168.333333  302.30
# 4       15.000000  148.00
#
# [5 rows x 384 columns]

# %%
print(data.columns)
# Out:
# Index(['slno', 'grp', 'Round_Centre', 'FSU_number', 'Round', 'Schedule_Number',
#        'Sample', 'Sector', 'state', 'State_Region',
#        ...
#        'pickle_v', 'sauce_jam_v', 'Othrprocessed_v', 'Beveragestotal_v',
#        'foodtotal_v', 'foodtotal_q', 'state_1', 'Region', 'fruits_df_tt_v',
#        'fv_tot'],
#       dtype='object', length=384)

# %%
data['non_vegetarian'] = (data[['eggsno_q', 'fishprawn_q', 'goatmeat_q', 'beef_q', 'pork_q', 'chicken_q', 'othrbirds_q']].sum(axis=1) > 0).astype(int)

# %%
X = data[['Age','MPCE_MRP', 'Sex', 'Sector']]
y = data['non_vegetarian']

# %%
import statsmodels.api as sm
X = sm.add_constant(X)

# %%
probit_model = sm.Probit(y, X)
result = probit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.592537
#          Iterations 4
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:         non_vegetarian   No. Observations:                32342
# Model:                         Probit   Df Residuals:                    32338
# Method:                           MLE   Df Model:                            3
# Date:                Mon, 01 Jul 2024   Pseudo R-squ.:                0.007146
# Time:                        11:42:16   Log-Likelihood:                -19164.
# converged:                       True   LL-Null:                       -19302.
# Covariance Type:            nonrobust   LLR p-value:                 1.657e-59
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Age            0.0064      0.001     12.027      0.000       0.005       0.007
# MPCE_MRP   -3.161e-05   2.75e-06    -11.516      0.000    -3.7e-05   -2.62e-05
# Sex           -0.0183      0.022     -0.831      0.406      -0.061       0.025
# Sector         0.1907      0.017     11.023      0.000       0.157       0.225
# ==============================================================================
